# %%
import pandas as pd
import numpy as np
import io
from google.colab import files
sns.set_style("whitegrid")
# %matplotlib inline
import math
from scipy.stats import norm
import scipy.stats as stats
import random 
import math

# %% [markdown]
# 1.	Un fabricante de medicamentos afirmó que la potencia media de uno de sus antinflamatorios era 90%. Se probó una muestra aleatoria de n=120 cápsulas y se obtuvo una media muestral de x=89.7%, con una desviación estándar de s=.9%.
# Responde: ¿Los datos representan evidencia suficiente para refutar la afirmación del fabricante? Sea α=0.05.
#
# •	Plantea la hipótesis nula por probar
#
# •	Establece la hipótesis alternativa
#
# •	Efectúa una prueba estadística para la hipótesis nula y ofrece comentarios conclusivos
#
# ![image.png](data:image/png;base64,...)

# %%
mu = .9
n = 120
X = .897
s = .009

# %%
error_std = s/math.sqrt(n-1)
error_std
# Out:
# 0.0008250286473253901

# %%
Z = (X - mu)/error_std
Z
# Out:
# -3.6362373715452416

# %% [markdown]
# 2.	En un artículo se expresa que casi 35% de la población europea nace con los ojos color café, aunque no necesariamente permanecen así. Para probar la afirmación del artículo, se eligió una muestra aleatoria de 100 personas y se encontró que 30 tenían ojos cafés.
#
# Responde: ¿Hay evidencia suficiente para rebatir la afirmación del artículo? Usar α=0.01.

# %%
n_2 = 100
